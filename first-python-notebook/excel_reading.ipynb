# %%
import pandas

path = "./statics/sampledataworkorders.xlsx"
data = pandas.read_excel(path, sheet_name="WOs")

# Affiche le type des colonnes
print(data.dtypes)
# Affiche des données diverses relatives aux données
print(data.info(verbose=True))
# Compte le nombre de cellule non-nulle de chaque ligne/colonne
print(data.count())
# Affiche les colonnes de votre DataFrame
print(data.columns)
# Converti les DataFrames en JSON
print(f"{data.to_json()}\n")
# Converti les DataFrames en dictionnaire
print(f"{data.to_dict()}\n")
# Out:
# WO                   object
# District             object
# LeadTech             object
# Service              object
# Rush                 object
# ReqDate      datetime64[ns]
# WorkDate     datetime64[ns]
# Techs                 int64
# WtyLbr               object
# WtyParts             object
# LbrHrs              float64
# PartsCost           float64
# Payment              object
# Wait                float64
# LbrRate               int64
# LbrCost             float64
# LbrFee              float64
# PartsFee            float64
# TotalCost           float64
# TotalFee            float64
# ReqDay               object
# WorkDay              object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   WO         1000 non-null   object
#  1   District   1000 non-null   object
#  2   LeadTech   1000 non-null   object
#  3   Service    1000 non-null   object
#  4   Rush       103 non-null    object
#  5   ReqDate    1000 non-null   datetime64[ns]
#  6   WorkDate   858 non-null    datetime64[ns]
#  7   Techs      1000 non-null   int64
#  8   WtyLbr     41 non-null     object
#  9   WtyParts   94 non-null     object
#  10  LbrHrs     858 non-null    float64
#  11  PartsCost  1000 non-null   float64
#  12  Payment    1000 non-null   object
#  13  Wait       858 non-null    float64
#  14  LbrRate    1000 non-null   int64
#  15  LbrCost    1000 non-null   float64
#  16  LbrFee     1000 non-null   float64
#  17  PartsFee   1000 non-null   float64
#  18  TotalCost  1000 non-null   float64
#  19  TotalFee   1000 non-null   float64
#  20  ReqDay     1000 non-null   object
#  21  WorkDay    1000 non-null   object
# dtypes: datetime64[ns](2), float64(8), int64(2), object(10)
# memory usage: 172.0+ KB
# None
# WO           1000
# District     1000
# LeadTech     1000
# Service      1000
# Rush          103
# ReqDate      1000
# WorkDate      858
# Techs        1000
# WtyLbr         41
# WtyParts       94
# LbrHrs        858
# PartsCost    1000
# Payment      1000
# Wait          858
# LbrRate      1000
# LbrCost      1000
# LbrFee       1000
# PartsFee     1000
# TotalCost    1000
# TotalFee     1000
# ReqDay       1000
# WorkDay      1000
# dtype: int64
# Index(['WO', 'District', 'LeadTech', 'Service', 'Rush', 'ReqDate', 'WorkDate',
#        'Techs', 'WtyLbr', 'WtyParts', 'LbrHrs', 'PartsCost', 'Payment', 'Wait',
#        'LbrRate', 'LbrCost', 'LbrFee', 'PartsFee', 'TotalCost', 'TotalFee',
#        'ReqDay', 'WorkDay'],
#       dtype='object')
207":"A00307","208":"A00308","209":"A00309","210":"A00310","211":"A00311","212":"A00312","213":"A00313","214":"A00314","215":"A00315","216":"A00316","217":"A00317","218":"A00318","219":"A00319","220":"A00320","221":"A00321","222":"A00322","223":"A00323","224":"A00324","225":"A00325","226":"A00326","227":"A00327","228":"A00328","229":"A00329","230":"A00330","231":"A00331","232":"A00332","233":"A00333","234":"A00334","235":"A00335","236":"A00336","237":"A00337","238":"A00338","239":"A00339","240":"A00340","241":"A00341","242":"A00342","243":"A00343","244":"A00344","245":"A00345","246":"A00346","247":"A00347","248":"A00348","249":"A00349","250":"A00350","251":"A00351","252":"A00352","253":"A00353","254":"A00354","255":"A00355","256":"A00356","257":"A00357","258":"A00358","259":"A00359","260":"A00360","261":"A00361","262":"A00362","263":"A00363","264":"A00364","265":"A00365","266":"A00366","267":"A00367","268":"A00368","269":"A00369","270":"A00370","271":"A00371","272":"A00372","273":"A ...
#
# {'WO': {0: 'A00100', 1: 'A00101', 2: 'A00102', 3: 'A00103', 4: 'A00104', 5: 'A00105', 6: 'A00106', 7: 'A00107', 8: 'A00108', 9: 'A00109', 10: 'A00110', 11: 'A00111', 12: 'A00112', 13: 'A00113', 14: 'A00114', 15: 'A00115', 16: 'A00116', 17: 'A00117', 18: 'A00118', 19: 'A00119', 20: 'A00120', 21: 'A00121', 22: 'A00122', 23: 'A00123', 24: 'A00124', 25: 'A00125', 26: 'A00126', 27: 'A00127', 28: 'A00128', 29: 'A00129', 30: 'A00130', 31: 'A00131', 32: 'A00132', 33: 'A00133', 34: 'A00134', 35: 'A00135', 36: 'A00136', 37: 'A00137', 38: 'A00138', 39: 'A00139', 40: 'A00140', 41: 'A00141', 42: 'A00142', 43: 'A00143', 44: 'A00144', 45: 'A00145', 46: 'A00146', 47: 'A00147', 48: 'A00148', 49: 'A00149', 50: 'A00150', 51: 'A00151', 52: 'A00152', 53: 'A00153', 54: 'A00154', 55: 'A00155', 56: 'A00156', 57: 'A00157', 58: 'A00158', 59: 'A00159', 60: 'A00160', 61: 'A00161', 62: 'A00162', 63: 'A00163', 64: 'A00164', 65: 'A00165', 66: 'A00166', 67: 'A00167', 68: 'A00168', 69: 'A00169', 70: 'A00170', 71: 'A00171', 72: 'A00172', 73: 'A00173', 74: 'A00174', 75: 'A00175', 76: 'A00176', 77: 'A00177', 78: 'A00178', 79: 'A00179', 80: 'A00180', 81: 'A00181', 82: 'A00182', 83: 'A00183', 84: 'A00184', 85: 'A00185', 86: 'A00186', 87: 'A00187', 88: 'A00188', 89: 'A00189', 90: 'A00190', 91: 'A00191', 92: 'A00192', 93: 'A00193', 94: 'A00194', 95: 'A00195', 96: 'A00196', 97: 'A00197', 98: 'A00198', 99: 'A00199', 100: 'A00200', 101: 'A00201', 102: 'A00202', 103: 'A00203', 104: 'A00204', 105: 'A00205', 106: 'A00206', 107: 'A00207', 108: 'A00208', 109: 'A00209', 110: 'A00210', 111: 'A00211', 112: 'A00212', 113: 'A00213', 114: 'A00214', 115: 'A00215', 116: 'A00216', 117: 'A00217', 118: 'A00218', 119: 'A00219', 120: 'A00220', 121: 'A00221', 122: 'A00222', 123: 'A00223', 124: 'A00224', 125: 'A00225', 126: 'A00226', 127: 'A00227', 128: 'A00228', 129: 'A00229', 130: 'A00230', 131: 'A00231', 132: 'A00232', 133: 'A00233', 134: 'A00234', 135: 'A00235', 136: 'A00236', 137: 'A00237', 138: 'A00238', 139: 'A00239', 140: 'A00240', 141: 'A00241', 142: 'A00242', 143: 'A00243', 144: 'A00244', 145: 'A00245', 146: 'A00246', 147: 'A00247', 148: 'A00248', 149: 'A00249', 150: 'A00250', 151: 'A00251', 152: 'A00252', 153: 'A00253', 154: 'A00254', 155: 'A00255', 156: 'A00256', 157: 'A00257', 158: 'A00258', 159: 'A00259', 160: 'A00260', 161: 'A00261', 162: 'A00262', 163: 'A00263', 164: 'A00264', 165: 'A00265', 166: 'A00266', 167: 'A00267', 168: 'A00268', 169: 'A00269', 170: 'A00270', 171: 'A00271', 172: 'A00272', 173: 'A00273', 174: 'A00274', 175: 'A00275', 176: 'A00276', 177: 'A00277', 178: 'A00278', 179: 'A00279', 180: 'A00280', 181: 'A00281', 182: 'A00282', 183: 'A00283', 184: 'A00284', 185: 'A00285', 186: 'A00286', 187: 'A00287', 188: 'A00288', 189: 'A00289', 190: 'A00290', 191: 'A00291', 192: 'A00292', 193: 'A00293', 194: 'A00294', 195: 'A00295', 196: 'A00296', 197: 'A00297', 198: 'A00298', 199: 'A00299', 200: 'A00300', 201: 'A00301', 202: 'A00302', 203: 'A00303', 204: 'A00304', 205: 'A00305', 206: 'A00306', 207: 'A00307', 208: 'A00308', 209: 'A00309', 210: 'A00310', 211: 'A00311', 212: 'A00312', 213: 'A00313', 214: 'A00314', 215: 'A00315', 216: 'A00316', 217: 'A00317', 218: 'A00318', 219: 'A00319', 220: 'A00320', 221: 'A00321', 222: 'A00322', 223: 'A00323', 224: 'A00324', 225: 'A00325', 226: 'A00326', 227: 'A00327', 228: 'A00328', 229: 'A00329', 230: 'A00330', 231: 'A00331', 232: 'A00332', 233: 'A00333', 234: 'A00334', 235: 'A00335', 236: 'A00336', 237: 'A00337', 238: 'A00338', 239: 'A00339', 240: 'A00340', 241: 'A00341', 242: 'A00342', 243: 'A00343', 244: 'A00344', 245: 'A00345', 246: 'A00346', 247: 'A00347', 248: 'A00348', 249: 'A00349', 250: 'A00350', 251: 'A00351', 252: 'A00352', 253: 'A00353', 254: 'A00354', 255: 'A00355', 256: 'A00356', 257: 'A00357', 258: 'A00358', 259: 'A00359', 260: 'A00360', 261: 'A00361', 262: 'A00362', 263: 'A00363', 264: 'A00364', 265: 'A00365', 266: 'A00366', 267: 'A00367', 268: 'A00368', 269: 'A00369', 270: 'A00370', 271: 'A00371', 272: 'A00372', 273: 'A ...

# %%
print(data)
# Out:
#          WO   District LeadTech  Service Rush    ReqDate   WorkDate  Techs  \
# 0    A00100      North     Khan   Assess  NaN 2020-09-01 2020-09-15      2
# 1    A00101      South    Lopez  Replace  NaN 2020-09-01 2020-09-04      1
# 2    A00102    Central  Cartier  Deliver  NaN 2020-09-01 2020-09-17      1
# 3    A00103      South    Lopez  Deliver  NaN 2020-09-01 2020-09-17      1
# 4    A00104  Northwest  Cartier  Deliver  Yes 2020-09-01 2020-09-17      1
# ..      ...        ...      ...      ...  ...        ...        ...    ...
# 995  A01095  Southeast   Burton   Assess  NaN 2021-07-22        NaT      2
# 996  A01096  Northwest  Cartier   Repair  NaN 2021-07-22        NaT      1
# 997  A01097    Central  Cartier   Assess  NaN 2021-07-23        NaT      1
# 998  A01098       East     Ling  Deliver  NaN 2021-07-24        NaT      1
# 999  A01100       East     Ling   Assess  NaN 2021-07-29        NaT      2
#
#     WtyLbr WtyParts  ...  Payment  Wait LbrRate  LbrCost  LbrFee  PartsFee  \
# 0      NaN      NaN  ...  Account  14.0     140     70.0    70.0  360.0000
# 1      NaN      NaN  ...  Account   3.0      80     40.0    40.0   90.0416
# 2      NaN      NaN  ...     P.O.  16.0      80     20.0    20.0  120.0000
# 3      NaN      NaN  ...  Account  16.0      80     20.0    20.0   16.2500
# 4      NaN      NaN  ...  Account  16.0      80     20.0    20.0   45.2374
# ..     ...      ...  ...      ...   ...     ...      ...     ...       ...
# 995    NaN      NaN  ...   C.O.D.   NaN     140      0.0     0.0  237.2100
# 996    NaN      NaN  ...   C.O.D.   NaN      80      0.0     0.0  128.8115
# 997    NaN      NaN  ...   C.O.D.   NaN      80      0.0     0.0   84.8862
# 998    NaN      NaN  ...  Account   NaN      80      0.0     0.0  122.3195
# 999    NaN      NaN  ...   C.O.D.   NaN     140      0.0     0.0  210.4494
#
#      TotalCost  TotalFee  ReqDay  WorkDay
# 0     430.0000  430.0000     Tue      Tue
# 1     130.0416  130.0416     Tue      Fri
# 2     140.0000  140.0000     Tue      Thu
# 3      36.2500   36.2500     Tue      Thu
# 4      65.2374   65.2374     Tue      Thu
# ..         ...       ...     ...      ...
# 995   237.2100  237.2100     Thu      Sat
# 996   128.8115  128.8115     Thu      Sat
# 997    84.8862   84.8862     Fri      Sat
# 998   122.3195  122.3195     Sat      Sat
# 999   210.4494  210.4494     Thu      Sat
#
# [1000 rows x 22 columns]
